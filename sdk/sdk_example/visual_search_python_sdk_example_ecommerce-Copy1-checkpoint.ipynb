# %%
import sys
sys.path.append("../python/recoai_visual_search/")
from visual_search import RecoAIVisualSearch
from models import *
import json
from glob import glob
import ipyplot
from matplotlib import pyplot as plt
from tqdm import tqdm

# %%
api = RecoAIVisualSearch(bearer_token="secrettoken", address="http://localhost:8890")

# %% [markdown]
# Creating a collection to keep the images
# -------------
#
# In this case we are using MOBILE_NET_V2 as the feature extractor.

# %%
upsert_collection = UpsertCollection(
    config=GenericModelConfig(
        model_architecture=ModelArchitecture.MOBILE_NET_V2
    ), 
    name="images"
)
response = api.upsert_collection(upsert_collection)

# %% [markdown]
# Indexing local images
# -----------
#
# It is possible to index local images using `ImageBytes` or `ImageSource(url="link_to_image")`

# %%
for img_path in tqdm(sorted(glob("../../images/ecommerce-images/data/Apparel/Boys/Images/images_with_product_ids/*.jpg"))):
    image_id = img_path.split("/")[-1].split(".")[0]
    with open(img_path, "rb") as inp:
        image_bytes = list(inp.read())
    image_source = ImageSource(image_bytes=ImageBytes(image_bytes))
    add_image = AddImage(collection_name="images", id=image_id, source=image_source)
    resp = api.add_image(add_image)
# Out:
# 100%|██████████| 759/759 [01:58<00:00,  6.42it/s]

# %% [markdown]
# Searching for a cat
# -----------

# %%
img = plt.imread("../../images/ecommerce-images/data/Apparel/Boys/Images/images_with_product_ids/10054.jpg")
ipyplot.plot_images([img], img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-BLSoHHwtY9VAGGCw3jJUw2 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-BLSoHHwtY9VAGGCw3jJUw2 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-BLSoHHwtY9VAGGCw3jJUw2 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-BLSoHHwtY9VAGGCw3jJUw2:checked ~ #ipyplot-html-viewer-textarea-BLSoHHwtY9VAGGCw3jJUw2 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-BLSoHHwtY9VAGGCw3jJUw2:checked + #ipyplot-html-viewer-label-BLSoHHwtY9VAGGCw3jJUw2:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-BLSoHHwtY9VAGGCw3jJUw2">
#         <label id="ipyplot-html-viewer-label-BLSoHHwtY9VAGGCw3jJUw2" for="ipyplot-html-viewer-toggle-BLSoHHwtY9VAGGCw3jJUw2">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-BLSoHHwtY9VAGGCw3jJUw2" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-FSoB3Cb4cBWacgHyZXUA69 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FSoB3Cb4cBWacgHyZXUA69 {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69 {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69 img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FSoB3Cb4cBWacgHyZXUA69">
#     <div class="ipyplot-placeholder-div-FSoB3Cb4cBWacgHyZXUA69">
#         <div id="ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69-R9ZfSwTD8HKfGCMGafuftU" class="ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69-R9ZfSwTD8HKfGCMGafuftU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-FSoB3Cb4cBWacgHyZXUA69 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FSoB3Cb4cBWacgHyZXUA69 {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69 {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69 img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FSoB3Cb4cBWacgHyZXUA69">
#     <div class="ipyplot-placeholder-div-FSoB3Cb4cBWacgHyZXUA69">
#         <div id="ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69-R9ZfSwTD8HKfGCMGafuftU" class="ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FSoB3Cb4cBWacgHyZXUA69-R9ZfSwTD8HKfGCMGafuftU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
# Out:
# CPU times: user 187 ms, sys: 11 µs, total: 187 ms
# Wall time: 430 ms
# {'collection_name': 'images',
#  'results': [{'id': '10054', 'similarity': 0},
#   {'id': '4728', 'similarity': 1093241214},
#   {'id': '4202', 'similarity': 1093312557},
#   {'id': '52121', 'similarity': 1093681515},
#   {'id': '50718', 'similarity': 1093681515},
#   {'id': '35999', 'similarity': 1094314830},
#   {'id': '24909', 'similarity': 1094343361},
#   {'id': '34183', 'similarity': 1094374909}]}

# %%
from random import choice
from glob import glob

fn = choice(glob("../../images/art/resized/*.jpg"))

with open(fn, "rb") as inp:
    image_bytes = list(inp.read())
image_source = ImageSource(image_bytes=ImageBytes(image_bytes))
search_image = SearchImage(collection_name="images", n_results=8, source=image_source)
search_results = json.loads(api.search_image(search_image).content)

images_paths = []
image_labels = []
for result in search_results["results"]:
    fn = "../../images/art/resized/{}".format(result["id"])
    img = plt.imread(fn)
    image_labels.append(fn.split("/")[-1])
    images_paths.append(img)    
ipyplot.plot_images(images_paths, labels=image_labels, img_width=200)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-RwbLEPNbLNdZJNZyVB9KEK {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RwbLEPNbLNdZJNZyVB9KEK {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RwbLEPNbLNdZJNZyVB9KEK {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RwbLEPNbLNdZJNZyVB9KEK:checked ~ #ipyplot-html-viewer-textarea-RwbLEPNbLNdZJNZyVB9KEK {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RwbLEPNbLNdZJNZyVB9KEK:checked + #ipyplot-html-viewer-label-RwbLEPNbLNdZJNZyVB9KEK:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-RwbLEPNbLNdZJNZyVB9KEK">
#         <label id="ipyplot-html-viewer-label-RwbLEPNbLNdZJNZyVB9KEK" for="ipyplot-html-viewer-toggle-RwbLEPNbLNdZJNZyVB9KEK">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-RwbLEPNbLNdZJNZyVB9KEK" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-o6ARY54hiQHXTGTi6VFiaV {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-o6ARY54hiQHXTGTi6VFiaV">
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-N2Ko4eeopyu44GfNx9x72m" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vincent_van_Gogh_638.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-N2Ko4eeopyu44GfNx9x72m">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-HzQzPrrzZ3djJLzfgWoKsg" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vincent_van_Gogh_763.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-HzQzPrrzZ3djJLzfgWoKsg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-d8zcqjBKjuax4nUYtLhJLF" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Paul_Gauguin_271.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-d8zcqjBKjuax4nUYtLhJLF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-VjSragV6QC2xnmFmUoWnNp" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Gustave_Courbet_32.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-VjSragV6QC2xnmFmUoWnNp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-2Yuznq84wCtUXXAGSoHRRW" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vincent_van_Gogh_306.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-2Yuznq84wCtUXXAGSoHRRW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-MoWm9TNVreXwqWzo93BEGB" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vincent_van_Gogh_409.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-MoWm9TNVreXwqWzo93BEGB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-XZG5oMiqprA6Yq9QKhTBFy" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vincent_van_Gogh_769.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-XZG5oMiqprA6Yq9QKhTBFy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </d
#         <style>
#         #ipyplot-imgs-container-div-o6ARY54hiQHXTGTi6VFiaV {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-o6ARY54hiQHXTGTi6VFiaV">
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-N2Ko4eeopyu44GfNx9x72m" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vincent_van_Gogh_638.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-N2Ko4eeopyu44GfNx9x72m">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-HzQzPrrzZ3djJLzfgWoKsg" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vincent_van_Gogh_763.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-HzQzPrrzZ3djJLzfgWoKsg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-d8zcqjBKjuax4nUYtLhJLF" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Paul_Gauguin_271.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-d8zcqjBKjuax4nUYtLhJLF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-VjSragV6QC2xnmFmUoWnNp" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Gustave_Courbet_32.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-VjSragV6QC2xnmFmUoWnNp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-2Yuznq84wCtUXXAGSoHRRW" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vincent_van_Gogh_306.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-2Yuznq84wCtUXXAGSoHRRW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-MoWm9TNVreXwqWzo93BEGB" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vincent_van_Gogh_409.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-MoWm9TNVreXwqWzo93BEGB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-XZG5oMiqprA6Yq9QKhTBFy" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vincent_van_Gogh_769.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-XZG5oMiqprA6Yq9QKhTBFy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-o6ARY54hiQHXTGTi6VFiaV">
#         <div id="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-59tVUTQg9SVejVgxW7RFKc" class="ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Alfred_Sisley_37.jpg</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-o6ARY54hiQHXTGTi6VFiaV-59tVUTQg9SVejVgxW7RFKc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
choice(glob("../../images/art/resized/*.jpg"))
# Out:
# '../../images/art/resized/Albrecht_Dürer_304.jpg'
